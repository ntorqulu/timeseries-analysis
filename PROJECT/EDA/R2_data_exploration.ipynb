# %% [markdown]
# # EDA on R2 trains

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from scipy.stats import pearsonr

plt.style.use('ggplot')
base_dir = '../data/'

# %%
# Load full datasets efficiently
print("Loading full month timetables, trains (for line mapping) and weather...")
tt_files = glob.glob(os.path.join(base_dir, 'dynamic', 'timetables', '*.parquet'))
weather_files = glob.glob(os.path.join(base_dir, 'dynamic', 'weather', '*.parquet'))
train_files = glob.glob(os.path.join(base_dir, 'dynamic', 'trains', '*.parquet'))
stations_df = pd.read_parquet(os.path.join(base_dir, 'static', 'stations.parquet'))

tt_list = []
for f in tt_files:
    df = pd.read_parquet(f, columns=['train_id', 'station_id', 'planned_arrival', 'planned_departure', 'actual_arrival', 'actual_departure'])
    df = df.drop_duplicates(subset=['train_id', 'station_id'], keep='last')
    tt_list.append(df)
tt_df = pd.concat(tt_list, ignore_index=True)

print(tt_df.head())

# Create line mapping from ALL train files to guarantee R2 coverage
tr_df = pd.concat([pd.read_parquet(f, columns=['train_id', 'line_id']) for f in train_files], ignore_index=True)
line_map = tr_df.drop_duplicates(subset=['train_id']).set_index('train_id')['line_id']
tt_df['line_id'] = tt_df['train_id'].map(line_map).fillna('UNKNOWN')

# FILTER EXCLUSIVELY FOR LINE R2
tt_df = tt_df[tt_df['line_id'] == 'R2']
print(f"Filtered for Line R2! Total subset records: {len(tt_df)}")

w_df = pd.concat([pd.read_parquet(f) for f in weather_files], ignore_index=True)

tt_df['planned_arrival'] = pd.to_datetime(tt_df['planned_arrival'], errors='coerce')
tt_df['actual_arrival'] = pd.to_datetime(tt_df['actual_arrival'], errors='coerce')
tt_df['planned_departure'] = pd.to_datetime(tt_df['planned_departure'], errors='coerce')
tt_df['actual_departure'] = pd.to_datetime(tt_df['actual_departure'], errors='coerce')

tt_df['raw_arr_delay'] = (tt_df['actual_arrival'] - tt_df['planned_arrival']).dt.total_seconds() / 60
tt_df = tt_df.merge(stations_df[['station_id', 'name']], on='station_id', how='left')
print("Data loaded and delays computed!")
# Out:
# Loading full month timetables, trains (for line mapping) and weather...
#   train_id station_id      planned_arrival    planned_departure  \
# 0    77102      78600  2026-03-24 07:40:00  2026-03-24 07:40:00
# 1    95468      78706  2026-03-24 10:02:00  2026-03-24 10:02:00
# 2    95468      78705  2026-03-24 10:02:00  2026-03-24 10:02:00
# 3    95468      78703  2026-03-24 10:03:00  2026-03-24 10:03:00
# 4    95468      78704  2026-03-24 10:03:00  2026-03-24 10:03:00
#
#         actual_arrival     actual_departure
# 0  2026-03-24 07:38:00  2026-03-24 07:38:00
# 1  2026-03-24 10:18:00  2026-03-24 10:18:00
# 2  2026-03-24 10:18:00  2026-03-24 10:18:00
# 3  2026-03-24 10:19:00  2026-03-24 10:19:00
# 4  2026-03-24 10:19:00  2026-03-24 10:19:00
# Filtered for Line R2! Total subset records: 157316
# Data loaded and delays computed!

# %% [markdown]
# ## 1. Missing Values

# %%
null_pct = (tt_df.isnull().sum() / len(tt_df)) * 100

plt.figure(figsize=(10,5))
null_pct[null_pct > 0].sort_values(ascending=False).plot(kind='bar', color='orange')
plt.title('Percentage of Missing Values in Relevant Variables (Line R2)')
plt.ylabel('% Missing')
plt.show()

print("Missing Value Diagnostics:")
print(null_pct[null_pct > 0])
# Out:
# Missing Value Diagnostics:
# actual_arrival      0.092807
# actual_departure    0.092807
# raw_arr_delay       0.092807
# dtype: float64

# %% [markdown]
# - If `actual_arrival` is missing, the train may been cancelled or tracking failed. We will drop this rows when building the datasets since they lack the target variable.
# - Drop records missing essential temporal targets

# %%
tt_df = tt_df.dropna(subset=['actual_arrival', 'planned_arrival', 'raw_arr_delay'])
print(f"Records remaining after dropping fatal nulls: {len(tt_df)}")
# Out:
# Records remaining after dropping fatal nulls: 157170

# %% [markdown]
# ## 2. Outliers
#
# Are there impossible delays logged by the API?

# %%
plt.figure(figsize=(12,4))
sns.boxplot(x=tt_df['raw_arr_delay'], color='cyan')
plt.title('Unfiltered Delay Distribution (Detecting Outliers)')
plt.xlabel('Delay in Minutes')
plt.show()

# %% [markdown]
# There are some impossible negative values like `-1440` (train arrived a whole day early...) or delays over `500` minutes (which implies total breakdown rather than predictions). We will apply bounds to restrict our data to realistic delays.
# ### Between -60 minutes and 300 minutes.

# %%
tt_df = tt_df[(tt_df['raw_arr_delay'] >= -60) & (tt_df['raw_arr_delay'] <= 300)].copy()
tt_df['arr_delay'] = tt_df['raw_arr_delay'] # Clean feature
print("Records remaining after outlier bound restriction:", len(tt_df))
# Out:
# Records remaining after outlier bound restriction: 156886

# %% [markdown]
# ## 3. Influence of time (hour & week day)
#
# Extract temporal components to see if delay propagates more at certain days or hours.

# %%
tt_df['hour'] = tt_df['planned_arrival'].dt.hour
tt_df['day_of_week'] = tt_df['planned_arrival'].dt.day_name()

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.barplot(data=tt_df, x='hour', y='arr_delay', ci=None, color='teal', ax=ax[0])
ax[0].set_title('Average R2 Delay by Hour of Day')
ax[0].set_ylabel('Avg Delay (mins)')
ax[0].set_xlabel('Hour (24H)')

order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.barplot(data=tt_df, x='day_of_week', y='arr_delay', order=order, ci=None, color='indigo', ax=ax[1])
ax[1].set_title('Average R2 Delay by Day of Week')
ax[1].set_ylabel('Avg Delay (mins)')
plt.show()
# Out:
# /var/folders/cz/7ns86mjj5yj4wfpcmwnb0hjm0000gn/T/ipykernel_11794/7129821.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tt_df, x='hour', y='arr_delay', ci=None, color='teal', ax=ax[0])
# /var/folders/cz/7ns86mjj5yj4wfpcmwnb0hjm0000gn/T/ipykernel_11794/7129821.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tt_df, x='day_of_week', y='arr_delay', order=order, ci=None, color='indigo', ax=ax[1])

# %% [markdown]
# We see that Mondays are the day of the week with most delays and that trains that pass between 9.00 and 22.00 get the most delays too.
# Conclusion:
# - hour and day_of_week must be passed as predictive features to the model

# %% [markdown]
# ![alt text](img/r2_stations.gif "Title")

# %% [markdown]
# ## 2. Bottleneck edges (delay growth between stations)
#
# Where is teh train physically losing the most time compared to the planned timetables

# %%
st_counts = tt_df['name'].value_counts()
valid_stations = st_counts[st_counts > 50].index
st_delays = tt_df[tt_df['name'].isin(valid_stations)].groupby('name')['arr_delay'].mean().sort_values(ascending=False)

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
st_delays.head(10)[::-1].plot(kind='barh', ax=ax[0], color='salmon')
ax[0].set_title('Top 10 Most Delayed R2 Stations')

st_delays.tail(10)[::-1].plot(kind='barh', ax=ax[1], color='lightblue')
ax[1].set_title('Top 10 Least Delayed R2 Stations')
plt.tight_layout()
plt.show()

print("\n--- Bottleneck Edges ---")
tt_sorted = tt_df.sort_values(['train_id', 'planned_arrival']).copy()
tt_sorted['next_station'] = tt_sorted.groupby('train_id')['name'].shift(-1)
tt_sorted['edge_delay_growth'] = (
    (tt_sorted.groupby('train_id')['actual_arrival'].shift(-1) - tt_sorted['actual_departure']).dt.total_seconds() / 60 - 
    (tt_sorted.groupby('train_id')['planned_arrival'].shift(-1) - tt_sorted['planned_departure']).dt.total_seconds() / 60
)
tt_sorted = tt_sorted[(tt_sorted['edge_delay_growth'] > -30) & (tt_sorted['edge_delay_growth'] < 60)]
edge_counts = tt_sorted.groupby(['name', 'next_station']).size()
valid_edges = edge_counts[edge_counts > 20].index
edge_delays = tt_sorted.set_index(['name', 'next_station']).loc[tt_sorted.set_index(['name', 'next_station']).index.intersection(valid_edges)]\
    .groupby(['name', 'next_station'])['edge_delay_growth'].mean().sort_values(ascending=False).dropna()

edge_df = edge_delays.head(8).reset_index()
edge_df['Edge'] = edge_df['name'] + ' -> ' + edge_df['next_station']
plt.figure(figsize=(10, 4))
sns.barplot(data=edge_df, y='Edge', x='edge_delay_growth', palette='Reds_r')
plt.title('Top 8 Bottlenecks (R2 Delay Growth Segments)')
plt.xlabel('Added Delay (mins)')
plt.show()
# Out:
# --- Bottleneck Edges ---
# /var/folders/cz/7ns86mjj5yj4wfpcmwnb0hjm0000gn/T/ipykernel_11794/1852133923.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=edge_df, y='Edge', x='edge_delay_growth', palette='Reds_r')

# %% [markdown]
# ## R2 Weather correlation with p-values

# %%
tt_df['hour_trunc'] = tt_df['planned_arrival'].dt.floor('H')
w_df['hour_trunc'] = pd.to_datetime(w_df['timestamp']).dt.floor('H')

hourly_delays = tt_df.groupby('hour_trunc')['arr_delay'].mean().reset_index()
w_agg = w_df.groupby('hour_trunc')[['temperature', 'precipitation', 'windspeed', 'cloudcover']].mean().reset_index()
merged_weather = pd.merge(hourly_delays, w_agg, on='hour_trunc', how='inner')

merged_weather['is_raining'] = merged_weather['precipitation'] > 0.0
plt.figure(figsize=(8, 4))
sns.boxplot(data=merged_weather, x='is_raining', y='arr_delay', palette='coolwarm')
plt.title('R2 Delay Impact: Raining vs Not Raining')
plt.ylabel('Average Hourly Delay (mins)')
plt.xlabel('Is Precipitation > 0?')
plt.show()

print("--- STATISTICAL P-VALUES ---")
for col in ['temperature', 'precipitation', 'windspeed', 'cloudcover']:
    valid = merged_weather.dropna(subset=['arr_delay', col])
    corr, p_value = pearsonr(valid['arr_delay'], valid[col])
    print(f"{col.capitalize():>13} | Corr: {corr:+.3f} | P-value: {p_value:.2e}")
# Out:
# /var/folders/cz/7ns86mjj5yj4wfpcmwnb0hjm0000gn/T/ipykernel_11794/3113168430.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   tt_df['hour_trunc'] = tt_df['planned_arrival'].dt.floor('H')
# /var/folders/cz/7ns86mjj5yj4wfpcmwnb0hjm0000gn/T/ipykernel_11794/3113168430.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   w_df['hour_trunc'] = pd.to_datetime(w_df['timestamp']).dt.floor('H')
# /var/folders/cz/7ns86mjj5yj4wfpcmwnb0hjm0000gn/T/ipykernel_11794/3113168430.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=merged_weather, x='is_raining', y='arr_delay', palette='coolwarm')
# --- STATISTICAL P-VALUES ---
#   Temperature | Corr: -0.135 | P-value: 1.25e-04
# Precipitation | Corr: -0.082 | P-value: 2.04e-02
#     Windspeed | Corr: +0.155 | P-value: 1.01e-05
#    Cloudcover | Corr: -0.098 | P-value: 5.38e-03

# %% [markdown]
# Old comment for R1:
# - **Temperature (p < 0.001)**: Highly statistically significant (p = 4.10e-12). Changes in temperature robustly and linearly push delays upwards.
# - **Windspeed (p < 0.01)**: minor positive correlation.
# - **Precipitation (p > 0.05)**: statistically insignificant (p = ~0.096). Rain on isolated Line R2 intervals is effectively random noise for average delays right now.
# - **Cloudcover**:insignificant.
#
# Comment for R2: all correlations are weak.

# %% [markdown]
# ## Conclusions
# - filter non-nulls
# - bound outliers
# - compute temporal elements: hour and day_of_week
# - map weather features: drop precipitation/cloudcover as p-value failure. retain temperature and windspeed
# - compute lag edges: engineer a previous_Station_delay to capture propagation delays across bottlenecks

# %%
example_timetables_df = pd.read_parquet(tt_files[0])
print("\nExample Timetable Data (First File):")
print(example_timetables_df.head())
# Out:
# Example Timetable Data (First File):
#   train_id station_id      planned_arrival    planned_departure  \
# 0    77502      78700  2026-03-24 05:35:00  2026-03-24 05:38:00
# 1    77502      78710  2026-03-24 05:43:00  2026-03-24 05:44:00
# 2    77502      78704  2026-03-24 05:53:00  2026-03-24 05:57:00
# 3    77502      78703  2026-03-24 04:43:00  2026-03-24 06:01:00
# 4    77502      78705  2026-03-24 04:46:00  2026-03-24 06:08:00
#
#         actual_arrival     actual_departure platform stop_type observations  \
# 0  2026-03-24 05:38:00  2026-03-24 05:41:00     None         C
# 1  2026-03-24 05:46:00  2026-03-24 05:47:00        2         C
# 2  2026-03-24 05:56:00  2026-03-24 06:00:00        2         C
# 3  2026-03-24 04:46:00  2026-03-24 06:04:00        2         C
# 4  2026-03-24 04:49:00  2026-03-24 06:11:00        2         C
#
#              timestamp  stop_sequence composition
# 0  2026-03-24 02:44:05            NaN        None
# 1  2026-03-24 02:44:05            NaN        None
# 2  2026-03-24 02:44:05            NaN        None
# 3  2026-03-24 02:44:05            NaN        None
# 4  2026-03-24 02:44:05            NaN        None
